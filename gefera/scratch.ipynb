# %%
d = {'a':1, 'b':2}

# %%
tuple(d.values()) + tuple(d.values())
# Out:
# (1, 2, 1, 2)

# %%
def sumargs(*args):
    print(*args)

# %%
a = [1, 2, 3]
sumargs(*a)
# Out:
# 1 2 3

# %%
list
# Out:
# list

# %%
class TestSuper():
    
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
        
        self.f = None
            
    def perform(self):
        return self.f(self.a, self.b, self.c)
    
class TestProd(TestSuper):
    
    def __init__(self, a, b, c):
        super().__init__(a, b, c)
        self.f = lambda a, b, c: a * b * c
        
class TestSum(TestSuper):
    
    def __init__(self, a, b, c):
        super().__init__(a, b, c)
        self.f = lambda a, b, c: a + b + c

# %%
prod = TestProd(1, 2, 8)
prod.perform()
# Out:
# 16

# %%
summ = TestSum(1, 2, 8)
summ.perform()
# Out:
# 11

# %%
list(vars(summ).keys())
# Out:
# ['a', 'b', 'c', 'f']

# %%
s = 'trap'
'trap' == s
# Out:
# True

# %%
import matplotlib.pyplot as plt
t = np.linspace(0, 10, 1000)
y = np.cos(t / 0.5)
plt.plot(t, y)

# %%
dt = 1.0
ta = t - dt / 2
tb = t + dt / 2
ya = np.cos(ta / 0.5)
yb = np.cos(tb / 0.5)
yint = (ya + yb) / 2

# %%
plt.plot(t, yint)
plt.plot(t, y)

# %%
ytt
# Out:
# array([ 0.54030231,  0.55703917,  0.57355279, ...,  0.99150683,
#         0.98870462, -0.54772926])

# %%
tt
# Out:
# array([-0.5       , -0.48998999, -0.47997998, ...,  9.48998999,
#         9.5       , 10.5       ])
